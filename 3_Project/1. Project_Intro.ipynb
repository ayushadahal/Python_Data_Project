# %% [markdown]
# # Project: Exploratory Data Analysis in Python
#
# ## Objectives:
# 1. Investigate top-paying roles in the data science industry.
# 2. Use Python to explore real-life dataset on job postings.
# 3. For job seekers: use these insights to help find the best job opportunities.

# %% [markdown]
# ## Questions to Answer:
# 1. What are the most demanded skills for top 3 most popular data roles?
# 2. How are in-demand skills trending for Data Analysts?
# 3. How well do jobs and skills pay for Data Analysts?
# 4. What is the most optimal skill to learn for Data Analysts (high demand-high paying)?
